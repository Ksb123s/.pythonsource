# %%
from PIL import ImageGrab
import cv2
import keyboard
import mouse
import numpy as np

def set_roi():
    global ROI_SET, x1, y1, x2, y2
    ROI_SET = False
    print("Select your ROI using mouse drag.")
    while(mouse.is_pressed() == False):
        x1, y1 = mouse.get_position()
        while(mouse.is_pressed() == True):
            x2, y2 = mouse.get_position()
            while(mouse.is_pressed() == False):
                print("Your ROI : {0}, {1}, {2}, {3}".format(x1, y1, x2, y2))
                ROI_SET = True
                return
ROI_SET = False
x1, y1, x2, y2 = 0, 0, 0, 0
while True:
    keyboard.add_hotkey("ctrl+1", lambda: set_roi())

    if ROI_SET == True:
        image = cv2.cvtColor(np.array(ImageGrab.grab(bbox=(x1, y1, x2, y2))), cv2.COLOR_BGR2RGB)
        cv2.imshow("image", image)
        key = cv2.waitKey(100)
        if key == ord("q"):
            print("Quit")
            break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 22
#      20 x1, y1, x2, y2 = 0, 0, 0, 0
#      21 while True:
# ---> 22     keyboard.add_hotkey("ctrl+1", lambda: set_roi())
#      24     if ROI_SET == True:
#      25         image = cv2.cvtColor(np.array(ImageGrab.grab(bbox=(x1, y1, x2, y2))), cv2.COLOR_BGR2RGB)
#
# File c:\source\pythonsource\Lib\site-packages\keyboard\__init__.py:641, in add_hotkey(hotkey, callback, args, suppress, timeout, trigger_on_release)
#     637     callback = lambda callback=callback: callback(*args)
#     639 _listener.start_if_necessary()
# --> 641 steps = parse_hotkey_combinations(hotkey)
#     643 event_type = KEY_UP if trigger_on_release else KEY_DOWN
#     644 if len(steps) == 1:
#     645     # Deciding when to allow a KEY_UP event is far harder than I thought,
# ...

# %%
from PIL import ImageGrab
import cv2
import keyboard
import mouse
import numpy as np
import pytesseract

# # 비디오 캡처 객체 생성
# def set_roi():
#     global ROI_SET, x1, y1, x2, y2
#     ROI_SET = False
#     print("Select your ROI using mouse drag.")
#     while(mouse.is_pressed() == False):
#         x1, y1 = mouse.get_position()
#         while(mouse.is_pressed() == True):
#             x2, y2 = mouse.get_position()
#             while(mouse.is_pressed() == False):
#                 print("Your ROI : {0}, {1}, {2}, {3}".format(x1, y1, x2, y2))
#                 ROI_SET = True
#                 return

# ROI_SET = False
x1, y1, x2, y2 =0, 0, 1919, 1039
# keyboard.add_hotkey("ctrl+1", lambda: set_roi())


while True:
    # 프레임들 읽기
    

    # 영상 처리 코드 작성
    # 예시: 영상을 회색으로 변환하기
    # if ROI_SET == True:
        cv2.namedWindow('image', cv2.WINDOW_NORMAL)
        gray = cv2.cvtColor(np.array(ImageGrab.grab(bbox=(x1, y1, x2, y2))), cv2.COLOR_BGR2RGB)

        # 영상 출력
        cv2.imshow('image', gray)
      
        # 이미지에서 텍스트 추출
        text = pytesseract.image_to_string(gray, lang='eng')

        # 추출한 텍스트 출력
        print(text)
        # 'q' 키를 누르면 종료
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# 객체 해제

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\source\pythonsource\Lib\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...

# %%
from PIL import ImageGrab
import cv2
import keyboard
import mouse
import numpy as np
import pytesseract
import time

x1, y1, x2, y2 =0, 0, 1919, 1039

pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
String = []
while True:
    # 프레임들 읽기
    

    # 영상 처리 코드 작성
    # 예시: 영상을 회색으로 변환하기
    # if ROI_SET == True:
        cv2.namedWindow('image', cv2.WINDOW_NORMAL)
        gray = cv2.cvtColor(np.array(ImageGrab.grab(bbox=(x1, y1, x2, y2))), cv2.COLOR_BGR2RGB)
        # time.sleep(2)
        # 영상 출력
        cv2.imshow('image', gray)
        # configs = ('-l kor+eng --oem 3 --psm 11')
        # 이미지에서 텍스트 추출
        # text = pytesseract.image_to_string(gray, lang="kor")
        # time.sleep(2)
        # 추출한 텍스트 출력
        # print(text)
        # String.append(text)
        # time.sleep(2)
        # 'q' 키를 누르면 종료
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# 객체 해제
for x in String:
      print(x)
cv2.destroyAllWindows()
